# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# Updating files:  64% (2020/3117)
# Updating files:  65% (2027/3117)
# Updating files:  66% (2058/3117)
# Updating files:  67% (2089/3117)
# Updating files:  68% (2120/3117)
# Updating files:  69% (2151/3117)
# Updating files:  70% (2182/3117)
# Updating files:  71% (2214/3117)
# Updating files:  72% (2245/3117)
# Updating files:  73% (2276/3117)
# Updating files:  74% (2307/3117)
# Updating files:  75% (2338/3117)
# Updating files:  76% (2369/3117)
# Updating files:  77% (2401/3117)
# Updating files:  78% (2432/3117)
# Updating files:  79% (2463/3117)
# Updating files:  80% (2494/3117)
# Updating files:  81% (2525/3117)
# Updating files:  82% (2556/3117)
# Updating files:  83% (2588/3117)
# Updating files:  84% (2619/3117)
# Updating files:  85% (2650/3117)
# Updating files:  86% (2681/3117)
# Updating files:  87% (2712/3117)
# Updating files:  88% (2743/3117)
# Updating files:  89% (2775/3117)
# Updating files:  90% (2806/3117)
# ...

# %%
# %cd C:\Users\hawth\Desktop\ENFLUJO\models\research
# !protoc object_detection/protos/*.proto --python_out=.
# Install TensorFlow Object Detection API.
# !copy object_detection/packages/tf2/setup.py .
#  Copied setup.py manually
# !python -m pip install .
# Out:
# C:\Users\hawth\Desktop\ENFLUJO\models\research
# Processing c:\users\hawth\desktop\enflujo\models\research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 3.3/3.3 MB 23.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.2/7.2 MB 45.8 MB/s eta 0:00:00
# ...
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# ...
#      --------------------------------------- 38.6/38.6 MB 36.4 MB/s eta 0:00:00
# ...
#      --------------------------------------- 10.6/10.6 MB 50.4 MB/s eta 0:00:00
# ...
#      --------------------------------------- 14.7/14.7 MB 46.7 MB/s eta 0:00:00
# ...
#   Using cached opencv_python_headless-4.6.0.66-cp36-abi3-win_amd64.whl (35.5 MB)
# ...
#      ------------------------------------- 245.9/245.9 kB 15.7 MB/s eta 0:00:00
# ...
#      --------------------------------------- 14.7/14.7 MB 46.7 MB/s eta 0:00:00
# ...

# %%
# !python -m pip uninstall opencv-python-headless -y
# !python -m pip install opencv-python-headless==4.1.2.30
# Out:
# Found existing installation: opencv-python-headless 4.6.0.66
# Uninstalling opencv-python-headless-4.6.0.66:
#   Successfully uninstalled opencv-python-headless-4.6.0.66
# ERROR: Could not find a version that satisfies the requirement opencv-python-headless==4.1.2.30 (from versions: 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.14.51, 3.4.14.53, 3.4.15.55, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.2.52, 4.5.2.54, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66)
# ERROR: No matching distribution found for opencv-python-headless==4.1.2.30

# %%
# !python C:\Users\hawth\Desktop\ENFLUJO\models\research\object_detection\builders\model_builder_tf2_test.py
# Out:
# 2022-08-08 09:12:32.204507: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2022-08-08 09:12:32.205134: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Running tests under Python 3.9.7: C:\Users\hawth\anaconda3\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# C:\Users\hawth\anaconda3\lib\site-packages\object_detection\builders\model_builder.py:1102: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# ...

# %%
# !pip install -q kaggle
# !pip install -q kaggle-cli
# Out:
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [97 lines of output]
#   Building lxml version 4.0.0.
#   Building without Cython.
#   ERROR: b"'xslt-config' is not recognized as an internal or external command,\r\noperable program or batch file.\r\n"
#   ** make sure the development packages of libxml2 and libxslt are installed **
#
#   Using build configuration of libxslt
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\lxml
#   copying src\lxml\builder.py -> build\lib.win-amd64-3.9\lxml
#   copying src\lxml\cssselect.py -> build\lib.win-amd64-3.9\lxml
#   copying src\lxml\doctestcompare.py -> build\lib.win-amd64-3.9\lxml
#   copying src\lxml\ElementInclude.py -> build\lib.win-amd64-3.9\lxml
#   copying src\lxml\pyclasslookup.py -> build\lib.win-amd64-3.9\lxml
# ...

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'lixocity'
os.environ['KAGGLE_KEY'] = '76c64c42c825119d63215738ab2f6b26'

# %%
# %%bash
# mkdir /home/est3r30sc0p10/h/lab/enflujo-emporio-no-benevolente/entrenamiento/dataset
# !cd C:\Mythings\Projects\enflujo-emporio-no-benevolente\entrenamiento\dataset
# !dir
# !kaggle datasets download -d lixocity/beings --unzip
# !pip show kaggle
# Out:
# ...
#   0%|          | 0.00/101M [00:00<?, ?B/s]
#   1%|          | 1.00M/101M [00:00<00:10, 10.3MB/s]
#   7%|6         | 7.00M/101M [00:00<00:02, 38.2MB/s]
#  13%|#2        | 13.0M/101M [00:00<00:02, 46.3MB/s]
#  19%|#8        | 19.0M/101M [00:00<00:01, 49.9MB/s]
#  25%|##4       | 25.0M/101M [00:00<00:01, 53.2MB/s]
#  31%|###       | 31.0M/101M [00:00<00:01, 55.0MB/s]
#  37%|###6      | 37.0M/101M [00:00<00:01, 55.9MB/s]
#  42%|####2     | 43.0M/101M [00:00<00:01, 57.0MB/s]
#  48%|####8     | 49.0M/101M [00:00<00:00, 57.6MB/s]
#  54%|#####4    | 55.0M/101M [00:01<00:00, 57.0MB/s]
#  60%|######    | 61.0M/101M [00:01<00:00, 57.9MB/s]
#  66%|######6   | 67.0M/101M [00:01<00:00, 58.1MB/s]
#  72%|#######2  | 73.0M/101M [00:01<00:00, 58.5MB/s]
#  78%|#######7  | 79.0M/101M [00:01<00:00, 58.6MB/s]
#  84%|########3 | 85.0M/101M [00:01<00:00, 58.7MB/s]
#  90%|########9 | 91.0M/101M [00:01<00:00, 48.2MB/s]
#  96%|#########5| 97.0M/101M [00:01<00:00, 50.2MB/s]
# ...

# %%
# %%bash
# ls C:/Mythings/Projects/enflujo-emporio-no-benevolente/entrenamiento
# Out:
# ls: C:/Mythings/Projects/enflujo-emporio-no-benevolente/entrenamiento: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16736/410664090.py in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'ls C:/Mythings/Projects/enflujo-emporio-no-benevolente/entrenamiento\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2404             "8.1), use run_line_magic(magic_name, parameter_s).",
#    2405             DeprecationWarning,
# -> 2406             stacklevel=2,
#    2407         )
#    2408         # TODO: should we issue a loud deprecation warning here?
#
# ~\anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140     def _make_script_magic(self, name):
# ...

# %%
# !cd C:\Mythings\Projects\enflujo-emporio-no-benevolente\entrenamiento\dataset
# !dir
import tensorflow as tf

# %%
# !python dataset/generate_tf_records.py -l labelmap.txt -o dataset/train.record -i dataset/images -csv dataset/train_labels.csv
# !python dataset/generate_tf_records.py -l labelmap.txt -o dataset/test.record -i dataset/images -csv dataset/test_labels.csv
# Out:
# Traceback (most recent call last):
#   File "C:\Mythings\Projects\enflujo-emporio-no-benevolente\entrenamiento\dataset\generate_tf_records.py", line 133, in <module>
#     tf_record = TFRecord(args.labelmap_file)
#   File "C:\Mythings\Projects\enflujo-emporio-no-benevolente\entrenamiento\dataset\generate_tf_records.py", line 21, in __init__
#     f = open(labelmap_file, "r")
# FileNotFoundError: [Errno 2] No such file or directory: 'labelmap.txt'
# Traceback (most recent call last):
#   File "C:\Mythings\Projects\enflujo-emporio-no-benevolente\entrenamiento\dataset\generate_tf_records.py", line 133, in <module>
#     tf_record = TFRecord(args.labelmap_file)
#   File "C:\Mythings\Projects\enflujo-emporio-no-benevolente\entrenamiento\dataset\generate_tf_records.py", line 21, in __init__
#     f = open(labelmap_file, "r")
# FileNotFoundError: [Errno 2] No such file or directory: 'labelmap.txt'

# %%
# %cd /home/est3r30sc0p10/h/lab/enflujo-emporio-no-benevolente/entrenamiento
# !wget http://download.tensorflow.org/models/object_detection/classification/tf2/20200710/mobilenet_v2.tar.gz
# !tar -xvf mobilenet_v2.tar.gz
# !rm mobilenet_v2.tar.gz
# Out:
# /home/est3r30sc0p10/h/lab/enflujo-emporio-no-benevolente/entrenamiento
# --2022-08-02 05:24:23--  http://download.tensorflow.org/models/object_detection/classification/tf2/20200710/mobilenet_v2.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.78.176, 2800:3f0:4005:40c::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.78.176|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8404070 (8,0M) [application/x-tar]
# Saving to: ‘mobilenet_v2.tar.gz’
#
# mobilenet_v2.tar.gz 100%[===================>]   8,01M  17,5MB/s    in 0,5s
#
# 2022-08-02 05:24:24 (17,5 MB/s) - ‘mobilenet_v2.tar.gz’ saved [8404070/8404070]
#
# mobilenet_v2/
# mobilenet_v2/mobilenet_v2.ckpt-1.index
# mobilenet_v2/checkpoint
# mobilenet_v2/mobilenet_v2.ckpt-1.data-00001-of-00002
# mobilenet_v2/mobilenet_v2.ckpt-1.data-00000-of-00002

# %%
# !wget https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/ssd_mobilenet_v2_320x320_coco17_tpu-8.config
# !mv ssd_mobilenet_v2_320x320_coco17_tpu-8.config mobilenet_v2.config
# Out:
# --2022-08-02 05:24:24--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/ssd_mobilenet_v2_320x320_coco17_tpu-8.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4484 (4,4K) [text/plain]
# Saving to: ‘ssd_mobilenet_v2_320x320_coco17_tpu-8.config’
#
# ssd_mobilenet_v2_32 100%[===================>]   4,38K  --.-KB/s    in 0s
#
# 2022-08-02 05:24:25 (16,0 MB/s) - ‘ssd_mobilenet_v2_320x320_coco17_tpu-8.config’ saved [4484/4484]

# %%
num_classes = 1
batch_size = 1
num_steps = 7500
num_eval_steps = 1000

train_record_path = 'dataset/train.record'
test_record_path = 'dataset/test.record'
model_dir = 'training/'
labelmap_path = 'labelmap.pbtxt'

pipeline_config_path = 'mobilenet_v2.config'
fine_tune_checkpoint = 'mobilenet_v2/mobilenet_v2.ckpt-1'

# %%
import re

with open(pipeline_config_path) as f:
    config = f.read()

with open(pipeline_config_path, 'w') as f:

  # Set labelmap path
  config = re.sub('label_map_path: ".*?"', 
             'label_map_path: "{}"'.format(labelmap_path), config)
  
  # Set fine_tune_checkpoint path
  config = re.sub('fine_tune_checkpoint: ".*?"',
                  'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), config)
  
  # Set train tf-record file path
  config = re.sub('(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 
                  'input_path: "{}"'.format(train_record_path), config)
  
  # Set test tf-record file path
  config = re.sub('(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 
                  'input_path: "{}"'.format(test_record_path), config)
  
  # Set number of classes.
  config = re.sub('num_classes: [0-9]+',
                  'num_classes: {}'.format(num_classes), config)
  
  # Set batch size
  config = re.sub('batch_size: [0-9]+',
                  'batch_size: {}'.format(batch_size), config)
  
  # Set training steps
  config = re.sub('num_steps: [0-9]+',
                  'num_steps: {}'.format(num_steps), config)
  
  f.write(config)

# %%
# !python models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_config_path} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --sample_1_of_n_eval_examples=1 \
    --num_eval_steps={num_eval_steps}
# Out:
# 2022-08-02 05:24:25.534807: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-02 05:24:28.418144: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2022-08-02 05:24:28.418173: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: est3r30sc0p10-GP66-Leopard-11UG
# 2022-08-02 05:24:28.418178: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: est3r30sc0p10-GP66-Leopard-11UG
# 2022-08-02 05:24:28.418313: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 510.73.5
# 2022-08-02 05:24:28.418333: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 510.73.5
# ...
